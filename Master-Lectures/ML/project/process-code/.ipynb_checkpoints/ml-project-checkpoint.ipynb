# %% [markdown]
# # Impact of Prompting Strategies on Information Extraction from AI News Articles Using Open-Source LLMs

# %%
import pandas as pd

# Import dataset
df = pd.read_csv("MIT_AI_ARTICLES.csv")

print("Original article number:", len(df))

# Hold on only necessary columns
df = df[[
    "title",
    "publication_date",
    "summary",
    "body",
    "url"
]]

# Remove the ones with an empty Body.
df = df.dropna(subset=["body"])

# Calculate word count
df["word_count"] = df["body"].astype(str).str.split().str.len()

# Remove shorter or longer articles
clean_df = df[
    (df["word_count"] >= 200) &
    (df["word_count"] <= 3000)
]

print("Number of cleaned articles:", len(clean_df))

# Save
clean_df.to_csv("clean_articles.csv", index=False)

clean_df.head()
# Out:
# Original article number: 314
# Number of cleaned articles: 314
#                                                title publication_date  \
# 0  A new model predicts how molecules will dissol...  August 19, 2025
# 1  Researchers glimpse the inner workings of prot...  August 18, 2025
# 2  How AI could speed the development of RNA vacc...  August 15, 2025
# 3  Using generative AI, researchers design compou...  August 14, 2025
# 4  A new way to test how well AI systems classify...  August 13, 2025
#
#                                              summary  \
# 0  Solubility predictions could make it easier to...
# 1  A new approach can reveal the features AI mode...
# 2  MIT engineers used a machine-learning model to...
# 3  The team used two different AI approaches to d...
# 4  As large language models increasingly dominate...
#
#                                                 body  \
# 0  Using machine learning, MIT chemical engineers...
# 1  Within the past few years, models that can pre...
# 2  Using artificial intelligence, MIT researchers...
# 3  With help from artificial intelligence, MIT re...
# 4  Is this movie review a rave or a pan? Is this ...
#
#                                                  url  word_count
# 0  https://news.mit.edu/2025/new-model-predicts-h...        1149
# 1  https://news.mit.edu/2025/researchers-glimpse-...        1025
# 2  https://news.mit.edu/2025/how-ai-could-speed-d...        1006
# 3  https://news.mit.edu/2025/using-generative-ai-...        1076
# 4  https://news.mit.edu/2025/new-way-test-how-wel...        1186
